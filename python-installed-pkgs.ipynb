# %%
import pip
import pandas as pd
from IPython.display import display

installed_packages = pip.get_installed_distributions()
installed_packages_list = [(i.key, i.version) for i in installed_packages]
df = pd.DataFrame.from_records(installed_packages_list)
with pd.option_context('display.max_rows', None):
    display(df)
# Out:
#                                       0            1
# 0                                  xlwt        1.2.0
# 1                            xlsxwriter        0.9.6
# 2                                  xlrd        1.0.0
# 3                                 wrapt       1.10.8
# 4                    widgetsnbextension        1.2.6
# 5                                 wheel       0.29.0
# 6                                  wget          3.2
# 7                              werkzeug      0.11.15
# 8                               wcwidth        0.1.7
# 9                            unicodecsv       0.14.1
# 10                            traitlets        4.3.1
# 11                              tornado        4.4.2
# 12                                toolz        0.8.2
# 13                            terminado          0.6
# 14                               tables        3.3.0
# 15                                sympy          1.0
# 16                          statsmodels        0.6.1
# 17                           sqlalchemy        1.1.5
# 18                               spyder        3.1.2
# 19                       sockjs-tornado        1.0.3
# 20                      snowballstemmer        1.2.1
# 21                                  six       1.10.0
# 22                       singledispatch      3.4.0.3
# 23                        simplegeneric        0.8.1
# 24                              shellpy        0.5.0
# 25                              seaborn        0.7.1
# 26                                scipy       0.18.1
# 27                         scikit-learn       0.18.1
# 28                         scikit-image       0.12.3
# 29                                 rpy2        2.8.5
# 30                            rope-py3k  0.9.4.post1
# 31                             requests       2.12.4
# 32                                redis       2.10.5
# 33                                 qtpy        1.2.1
# 34                            qtconsole        4.2.1
# 35                            qtawesome        0.4.3
# 36                                pyzmq       16.0.2
# 37                               pyyaml         3.12
# 38                                 pytz      2016.10
# 39                      python-dateutil        2.6.0
# 40                               pytest        3.0.5
# 41                               pyquil        0.0.2
# 42                            pyparsing        2.1.4
# 43                            pyopenssl       16.2.0
# 44                               pylint        1.6.4
# 45                             pygments        2.1.3
# 46                               pygit2       0.25.0
# 47                             pyflakes        1.5.0
# 48                            pydotplus        2.0.2
# 49                               pycurl       7.43.0
# 50                             pycrypto        2.6.1
# 51                            pycparser         2.17
# 52                              pycosat        0.6.1
# 53                             pybind11        2.1.0
# 54                               pyasn1        0.1.9
# 55                                   py       1.4.32
# 56                           ptyprocess        0.5.1
# 57                               psutil        5.0.1
# 58                       prompt-toolkit        1.0.9
# 59                                  ply          3.9
# 60                                  pip        9.0.1
# 61                               pillow        4.0.0
# 62                          pickleshare        0.7.4
# 63                              pexpect        4.2.1
# 64                                 pep8        1.7.0
# 65                                patsy        0.4.1
# 66                             pathlib2        2.2.0
# 67                                partd        0.3.7
# 68                               pandas       0.19.2
# 69                             openpyxl        2.4.1
# 70                                  odo        0.5.0
# 71                        octave-kernel       0.26.2
# 72                               oct2py        4.0.5
# 73                             numpydoc        0.6.0
# 74                                numpy       1.11.3
# 75                              numexpr        2.6.1
# 76                                numba       0.30.1
# 77                             notebook        4.3.1
# 78                                 nose        1.3.7
# 79                                 nltk        3.2.2
# 80                             networkx         1.11
# 81                             nbformat        4.2.0
# 82                            nbconvert        4.2.0
# 83                     multipledispatch        0.4.9
# 84                               mpmath         0.19
# 85                              mistune        0.7.3
# 86                           metakernel       0.20.1
# 87                           matplotlib        2.0.0
# 88                           markupsafe         0.23
# 89                                 lxml        3.7.2
# 90                               locket        0.2.0
# 91                             llvmlite       0.15.0
# 92                    lazy-object-proxy        1.2.2
# 93                              jupyter        1.0.0
# 94    jupyter-nbextensions-configurator        0.2.4
# 95                   jupyter-latex-envs      1.3.8.2
# 96      jupyter-highlight-selected-word       0.0.10
# 97                         jupyter-core        4.2.1
# 98         jupyter-contrib-nbextensions        0.2.6
# 99                 jupyter-contrib-core        0.3.0
# 100                     jupyter-console        5.0.0
# 101                      jupyter-client        4.4.0
# 102                          jsonschema        2.5.1
# 103                              jinja2        2.9.4
# 104                                jedi        0.9.0
# 105                               jdcal          1.3
# 106                        itsdangerous         0.24
# 107                               isort        4.2.5
# 108                          ipywidgets        5.2.2
# 109                             ipython        5.1.0
# 110                    ipython-genutils        0.1.0
# 111                           ipykernel        4.5.2
# 112                           imagesize        0.7.1
# 113                                idna          2.2
# 114                ibmquantumexperience        1.1.0
# 115                            heapdict        1.0.0
# 116                                h5py        2.6.0
# 117                            greenlet       0.4.11
# 118                            graphviz          0.6
# 119                              gevent        1.2.1
# 120                              future       0.16.0
# 121                               flask         0.12
# 122                          flask-cors        3.0.2
# 123                           fastcache        1.0.2
# 124                             ezvis3d          0.2
# 125                          et-xmlfile        1.0.1
# 126                 environment-kernels          1.0
# 127                            docutils       0.13.1
# 128                                dill        0.2.5
# 129                           decorator       4.0.11
# 130                           datashape        0.5.4
# 131                                dask       0.13.0
# 132                             cytoolz        0.8.2
# 133                              cython       0.25.2
# 134                              cycler       0.10.0
# 135                        cryptography        1.7.1
# 136                         contextlib2        0.5.4
# 137                           configobj        5.0.6
# 138                               conda       4.3.14
# 139                            colorama        0.3.7
# 140                              clyent        1.2.2
# 141                         cloudpickle        0.2.2
# 142                               click          6.7
# 143                               chest        0.2.3
# 144                             chardet        2.3.0
# 145                                cffi        1.9.1
# 146                          bottleneck        1.2.0
# 147                                boto       2.45.0
# 148                               bokeh       0.12.4
# 149                               blaze       0.10.1
# 150                            bitarray        0.8.1
# 151                      beautifulsoup4        4.5.3
# 152                         bash-kernel          0.6
# 153  backports.shutil-get-terminal-size        1.0.0
# 154                               babel        2.3.4
# 155                             astropy          1.3
# 156                             astroid        1.4.9
# 157                    anaconda-project        0.4.1
# 158                  anaconda-navigator          1.5
# 159                     anaconda-client        1.6.0
# 160                           alabaster        0.7.9
# 161                              sphinx        1.5.1
# 162                          setuptools       27.2.0
