# %%
installed.packages()
# Out:
#               Package       LibPath                      Version  Priority
# assertthat    assertthat    /opt/anaconda3/lib/R/library 0.1      NA
# backports     backports     /opt/anaconda3/lib/R/library 1.0.4    NA
# base          base          /opt/anaconda3/lib/R/library 3.3.2    base
# base64enc     base64enc     /opt/anaconda3/lib/R/library 0.1-3    NA
# BH            BH            /opt/anaconda3/lib/R/library 1.62.0-1 NA
# BiocGenerics  BiocGenerics  /opt/anaconda3/lib/R/library 0.20.0   NA
# BiocInstaller BiocInstaller /opt/anaconda3/lib/R/library 1.24.0   NA
# bitops        bitops        /opt/anaconda3/lib/R/library 1.0-6    NA
# bnlearn       bnlearn       /opt/anaconda3/lib/R/library 4.1.1    NA
# boot          boot          /opt/anaconda3/lib/R/library 1.3-18   NA
# broom         broom         /opt/anaconda3/lib/R/library 0.4.1    NA
# car           car           /opt/anaconda3/lib/R/library 2.1-4    NA
# ...
